# %%
# !pip install lightgbm

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.datasets import make_classification
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score


from sklearn import tree

# %%
# train_values = pd.read_csv( 'train_values.csv', index_col='building_id')
# train_labels = pd.read_csv( 'train_labels.csv', index_col='building_id')
cleaned_train_labels = pd.read_csv('../cleaned_train.csv')
# cleaned_train_labels # --> train

train = pd.read_pickle('../cleaned_train.pkl')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int32
#  1   damage_grade                            260601 non-null  int8
#  2   geo_level_1_id                          260601 non-null  int8
#  3   geo_level_2_id                          260601 non-null  int16
#  4   geo_level_3_id                          260601 non-null  int16
#  5   count_floors_pre_eq                     260601 non-null  int8
#  6   age                                     260601 non-null  int16
#  7   area_percentage                         260601 non-null  int8
#  8   height_percentage                       260601 non-null  int8
#  9   land_surface_condition                  260601 non-null  category
# ...

# %%
test = pd.read_pickle('../cleaned_test.pkl')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86868 entries, 0 to 86867
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   building_id                             86868 non-null  int32
#  1   geo_level_1_id                          86868 non-null  int8
#  2   geo_level_2_id                          86868 non-null  int16
#  3   geo_level_3_id                          86868 non-null  int16
#  4   count_floors_pre_eq                     86868 non-null  int8
#  5   age                                     86868 non-null  int16
#  6   area_percentage                         86868 non-null  int8
#  7   height_percentage                       86868 non-null  int8
#  8   land_surface_condition                  86868 non-null  category
#  9   foundation_type                         86868 non-null  category
# ...

# %%
cat_cols = train.select_dtypes(include=['category']).columns.to_list()
cat_cols
# Out:
# ['land_surface_condition',
#  'foundation_type',
#  'roof_type',
#  'ground_floor_type',
#  'other_floor_type',
#  'position',
#  'plan_configuration',
#  'legal_ownership_status']

# %%
oneHot = pd.get_dummies(train[cat_cols], prefix=cat_cols)
oneHot.transpose()
# Out:
#                           0       1       2       3       4       5       \
# land_surface_condition_n       0       0       0       0       0       0
# land_surface_condition_o       0       1       0       0       0       0
# land_surface_condition_t       1       0       1       1       1       1
# foundation_type_h              0       0       0       0       0       0
# foundation_type_i              0       0       0       0       0       0
# foundation_type_r              1       1       1       1       1       1
# foundation_type_u              0       0       0       0       0       0
# foundation_type_w              0       0       0       0       0       0
# roof_type_n                    1       1       1       1       1       1
# roof_type_q                    0       0       0       0       0       0
# roof_type_x                    0       0       0       0       0       0
# ground_floor_type_f            1       0       1       1       1       1
# ...

# %%
train = train.drop(columns=cat_cols)
train
# Out:
#         building_id  damage_grade  geo_level_1_id  geo_level_2_id  \
# 0            802906             3               6             487
# 1             28830             2               8             900
# 2             94947             3              21             363
# 3            590882             2              22             418
# 4            201944             3              11             131
# ...             ...           ...             ...             ...
# 260596       688636             2              25            1335
# 260597       669485             3              17             715
# 260598       602512             3              17              51
# 260599       151409             2              26              39
# 260600       747594             3              21               9
#
#         geo_level_3_id  count_floors_pre_eq  age  area_percentage  \
# 0                12198                    2   30                6
# ...

# %%
train = pd.concat([train, oneHot], axis=1)
train
# Out:
#         building_id  damage_grade  geo_level_1_id  geo_level_2_id  \
# 0            802906             3               6             487
# 1             28830             2               8             900
# 2             94947             3              21             363
# 3            590882             2              22             418
# 4            201944             3              11             131
# ...             ...           ...             ...             ...
# 260596       688636             2              25            1335
# 260597       669485             3              17             715
# 260598       602512             3              17              51
# 260599       151409             2              26              39
# 260600       747594             3              21               9
#
#         geo_level_3_id  count_floors_pre_eq  age  area_percentage  \
# 0                12198                    2   30                6
# ...

# %%
oneHot = pd.get_dummies(test[cat_cols], prefix=cat_cols)

test = test.drop(columns=cat_cols)

test = pd.concat([test, oneHot], axis=1)
test = test.set_index('building_id')
test
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 300051                   17             596           11307
# 99355                     6             141           11987
# 890251                   22              19           10044
# 745817                   26              39             633
# 421793                   17             289            7970
# ...                     ...             ...             ...
# 310028                    4             605            3623
# 663567                   10            1407           11907
# 1049160                  22            1136            7712
# 442785                    6            1041             912
# 501372                   26              36            6436
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 300051                         3   20                7                  6
# ...

# %%
X = train.drop(columns='damage_grade')
X = X.set_index('building_id')
X
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
# ...                     ...             ...             ...
# 688636                   25            1335            1621
# 669485                   17             715            2060
# 602512                   17              51            8163
# 151409                   26              39            1851
# 747594                   21               9            9101
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# ...

# %%
y = train.damage_grade
y
# Out:
# 0         3
# 1         2
# 2         3
# 3         2
# 4         3
#          ..
# 260596    2
# 260597    3
# 260598    3
# 260599    2
# 260600    3
# Name: damage_grade, Length: 260601, dtype: int8

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=240)

# %%
import lightgbm as lgb

d_train1 = lgb.Dataset(X_train, label=y_train)
#Parametros
params1={}
params1['learning_rate'] = 0.1
# params1['boosting_type'] ='goss'
params1['feature_fraction'] = 0.9
params1['sub_feature'] = 0.001
params1['num_leaves'] = 150
params1['verbose'] = 1000
params1['init_model'] = 'Booster'
params1['max_bin'] = 2000
params1['min_data_in_leaf'] = 15
params1['boosting_type'] = 'gbdt'
params1['metric'] = 'binary_logloss'
params1['max_depth'] = 10

#Entreno el modelo
clf1 = lgb.train(params1,d_train1,1000)
#Prediccion
preds1 = clf1.predict(X_valid)
# Out:
# [LightGBM] [Warning] Unknown parameter: init_model
# [LightGBM] [Warning] feature_fraction is set=0.9, sub_feature=0.001 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Unknown parameter: init_model
# [LightGBM] [Warning] feature_fraction is set=0.9, sub_feature=0.001 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.937945
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.824286
# [LightGBM] [Debug] init for col-wise cost 0.057301 seconds, init for row-wise cost 0.079680 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.066348 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 3651
# ...

# %%
preds_final1 = preds1.round().astype('int')
preds_final1
# Out:
# array([2, 2, 3, ..., 2, 2, 2])

# %%
#Error del modelo
rmse1 = np.sqrt(mean_squared_error(y_valid, preds_final1))
print("RMSE: %f" % (rmse1))
# Out:
# RMSE: 0.507838

# %%
f1_score(y_valid, preds_final1, average='micro')
# Out:
# 0.7467047831008614

# %%
0.7518 ##---> overfitea
# Out:
# 0.7518

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
sns.regplot(y_valid, preds_final1, fit_reg=True, scatter_kws={"s": 100})
# Out:
# C:\Users\003568613\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='damage_grade'>

# %% [markdown]
# ## Predicción

# %%
preds = clf1.predict(test)
predicciones = preds.round().astype('int')
predicciones
# Out:
# array([3, 2, 2, ..., 2, 2, 1])

# %%
submission_format = pd.read_csv('../TP1/submission_format.csv', index_col='building_id')
submission_format
# Out:
#              damage_grade
# building_id
# 300051                  1
# 99355                   1
# 890251                  1
# 745817                  1
# 421793                  1
# ...                   ...
# 310028                  1
# 663567                  1
# 1049160                 1
# 442785                  1
# 501372                  1
#
# [86868 rows x 1 columns]

# %%
my_submission = pd.DataFrame(data=predicciones, columns=submission_format.columns, index=submission_format.index)
my_submission
# Out:
#              damage_grade
# building_id
# 300051                  3
# 99355                   2
# 890251                  2
# 745817                  1
# 421793                  3
# ...                   ...
# 310028                  2
# 663567                  2
# 1049160                 2
# 442785                  2
# 501372                  1
#
# [86868 rows x 1 columns]

# %%
my_submission.to_csv('Submits/LightGBM.csv')

# %% [markdown]
# ## Por columna

# %%
X
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
# ...                     ...             ...             ...
# 688636                   25            1335            1621
# 669485                   17             715            2060
# 602512                   17              51            8163
# 151409                   26              39            1851
# 747594                   21               9            9101
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# ...

# %%
# X_2 = X[['geo_level_1_id', 'geo_level_2_id','geo_level_3_id', 'count_floors_pre_eq', 'age']]
X_2 = X.iloc[:, :7]
X_2
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
# ...                     ...             ...             ...
# 688636                   25            1335            1621
# 669485                   17             715            2060
# 602512                   17              51            8163
# 151409                   26              39            1851
# 747594                   21               9            9101
#
#              count_floors_pre_eq  age  area_percentage  height_percentage
# building_id
# 802906                         2   30                6                  5
# ...

# %%
X_train2, X_valid2, y_train2, y_valid2 = train_test_split(X_2, y, test_size=0.20, random_state=240)

# %%
d_train2=lgb.Dataset(X_train2, label=y_train2)
#Parametros
params2={
'learning_rate': 0.9,
# 'boosting': dart',
'data' : 'train_data_file',
#'boosting_type':'goss',
'feature_fraction': 1,
'sub_feature': 0.1,
'tree_learner': 'voting',
'num_threads': 15,
'num_leaves': 290,
'verbose': 6,
# 'init_model': 'Booster',
'max_bin': 200,
'pos_bagging_fraction': 0.9}

#Entreno el modelo
clf2 = lgb.train(params2,d_train2,2000)

#Prediccion
preds2 = clf2.predict(X_valid2)
# Out:
# [LightGBM] [Warning] feature_fraction is set=1, sub_feature=0.1 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] feature_fraction is set=1, sub_feature=0.1 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.016531
# [LightGBM] [Debug] init for col-wise cost 0.000008 seconds, init for row-wise cost 0.005964 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 576
# [LightGBM] [Info] Number of data points in the train set: 208480, number of used features: 7
# [LightGBM] [Info] Start training from score 2.239539
# [LightGBM] [Debug] Trained a tree with leaves = 290 and depth = 21
# ...

# %%
preds_final2 = preds2.round().astype('int')
preds_final2
# Out:
# array([2, 2, 3, ..., 3, 1, 2])

# %%
#Error del modelo
rmse2 = np.sqrt(mean_squared_error(y_valid2, preds_final2))
print("RMSE: %f" % (rmse2))
# Out:
# RMSE: 0.635129

# %%
f1_score(y_valid2, preds_final2.round().astype('int'), average='micro')
# Out:
# 0.6445194835095259

# %%
0.7318536937268806
# Out:
# 0.7318536937268806

# %% [markdown]
# ## Prediccion2

# %%
test
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 300051                   17             596           11307
# 99355                     6             141           11987
# 890251                   22              19           10044
# 745817                   26              39             633
# 421793                   17             289            7970
# ...                     ...             ...             ...
# 310028                    4             605            3623
# 663567                   10            1407           11907
# 1049160                  22            1136            7712
# 442785                    6            1041             912
# 501372                   26              36            6436
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 300051                         3   20                7                  6
# ...

# %%
preds2 = clf2.predict(test.iloc[:,:5])
predicciones2 = preds2.round().astype('int')
predicciones2
# Out:
# array([3, 2, 2, ..., 2, 2, 1])

# %%
submission_format2 = pd.read_csv('../TP1/submission_format.csv', index_col='building_id')
submission_format2
# Out:
#              damage_grade
# building_id
# 300051                  1
# 99355                   1
# 890251                  1
# 745817                  1
# 421793                  1
# ...                   ...
# 310028                  1
# 663567                  1
# 1049160                 1
# 442785                  1
# 501372                  1
#
# [86868 rows x 1 columns]

# %%
my_submission2 = pd.DataFrame(data=predicciones2, columns=submission_format2.columns, index=submission_format2.index)
my_submission2
# Out:
#              damage_grade
# building_id
# 300051                  3
# 99355                   2
# 890251                  2
# 745817                  1
# 421793                  3
# ...                   ...
# 310028                  2
# 663567                  3
# 1049160                 2
# 442785                  2
# 501372                  1
#
# [86868 rows x 1 columns]

# %%
my_submission2.to_csv('Submits/LightGBM_Cols.csv')
